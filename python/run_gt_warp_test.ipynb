# %%
import util;
import numpy as np;

path='/home/SSD3/maheen-data/temp/vanilla_train_bn_check/test_images/loss_final_val_ind.npy';
human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP.txt'
human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP_noIm.txt'
horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_train_allKP.txt'


out_human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP_minLoss.txt'
out_human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP_minLoss_noIm.txt'
out_horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_train_allKP_minLoss.txt'


path='/home/SSD3/maheen-data/temp/vanilla_train_bn_check/val/test_images/loss_final_val_ind.npy';
human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP.txt'
human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP_noIm.txt'
horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_val_allKP.txt'


out_human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP_minLoss.txt'
out_human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP_minLoss_noIm.txt'
out_horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_val_allKP_minLoss.txt'




losses=np.load(path);
# print losses
human_data=util.readLinesFromFile(human_path);
human_data_noIm=util.readLinesFromFile(human_path_noIm);

# print len(human_data),len(losses); 
losses=losses[:len(human_data)];
# print len(human_data),len(losses);

horse_data=util.readLinesFromFile(horse_path);
# print len(horse_data);

horse_data_uni,uni_idx,uni_rev_idx=np.unique(horse_data,True,True);
# print horse_data_uni.shape,uni_idx.shape,uni_rev_idx.shape

idx_keep=np.zeros(horse_data_uni.shape);
# print idx_keep.shape
for idx,horse_data_curr in enumerate(horse_data_uni):
    idx_human=np.where(uni_rev_idx==idx)[0];
    loss_rel=losses[idx_human];
    min_loss_idx=np.argmin(loss_rel);
    min_idx_final=idx_human[min_loss_idx];
    idx_keep[idx]=min_idx_final;

horse_data=np.array(horse_data);
human_data=np.array(human_data);
human_data_noIm=np.array(human_data_noIm)

idx_keep=idx_keep.astype(np.int);
horse_check=horse_data[idx_keep];
human_rel=human_data[idx_keep];
human_rel_noIm=human_data_noIm[idx_keep];

print horse_check.shape,human_rel.shape,human_rel_noIm.shape

util.writeFile(out_human_path,human_rel);
util.writeFile(out_human_path_noIm,human_rel_noIm);
util.writeFile(out_horse_path,horse_check);
# Out:
# (193,) (193,) (193,)

# %%
import util;

human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP.txt'
human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP_noIm.txt'
horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_train_allKP.txt'


out_human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP_minLoss.txt'
out_human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_train_allKP_minLoss_noIm.txt'
out_horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_train_allKP_minLoss.txt'

human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP.txt'
human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP_noIm.txt'
horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_val_allKP.txt'


out_human_path='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP_minLoss.txt'
out_human_path_noIm='/home/SSD3/maheen-data/horse_project/data_check/aflw/matches_5_val_allKP_minLoss_noIm.txt'
out_horse_path='/home/SSD3/maheen-data/horse_project/data_check/horse/matches_5_val_allKP_minLoss.txt'


paths_org=[horse_path,human_path,human_path_noIm];
paths_new=[out_horse_path,out_human_path,out_human_path_noIm];

# for i in range(1,3)
org_data=[np.array(util.readLinesFromFile(file_curr)) for file_curr in paths_org];
new_data=[np.array(util.readLinesFromFile(file_curr)) for file_curr in paths_new];

for idx_data_curr,data_curr in enumerate(new_data[1]):
    idx_rel=np.where(np.logical_and(org_data[1]==data_curr,org_data[0]==new_data[0][idx_data_curr]));
    for i in range(3):
        print i;
#         print org_data[i][idx_rel];
#         print new_data[i][idx_data_curr];
        assert org_data[i][idx_rel]==new_data[i][idx_data_curr];
print 'done'
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# ...
